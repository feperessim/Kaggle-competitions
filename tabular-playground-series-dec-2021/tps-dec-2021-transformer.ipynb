# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/tabular-playground-series-dec-2021/sample_submission.csv
# /kaggle/input/tabular-playground-series-dec-2021/train.csv
# /kaggle/input/tabular-playground-series-dec-2021/test.csv

# %%
import random
import warnings
import gc

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

warnings.filterwarnings("ignore")

# %%
seed=47

# %%
def evaluate_model(model, x, y):
    y_pred_prob = model.predict(x)
    acc = accuracy_score(y, y_pred_prob)
    return {'accuracy' : acc}

# %%
import numpy as np

def split_sequences(sequences, n_steps):
	X, y = list(), list()
	for i in range(len(sequences)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the dataset
		if end_ix > len(sequences):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1, -1]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

# %%
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow import keras

# source https://keras.io/examples/audio/transformer_asr/

class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, num_heads, feed_forward_dim, dropout_rate=0.1, activation="selu"):
        super().__init__()
        self.attn = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = keras.Sequential(
            [
                layers.Dense(feed_forward_dim, activation=activation),
                layers.Dense(embed_dim),
            ]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(dropout_rate)
        self.dropout2 = layers.Dropout(dropout_rate)

    def call(self, inputs, training):
        attn_output = self.attn(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)


class Transformer(keras.Model):
    def __init__(
            self,
            num_hid=64,  # embed_dim - num of features
            time_steps=1,
            nb_classes=7,
            num_head=2,
            num_feed_forward=128,  # pointwise dim
            num_layers_enc=4,
            dropout_rate=0.1,
            activation="relu"
    ):
        super().__init__()
        self.numlayers_enc = num_layers_enc
        self.enc_input = layers.Input((time_steps, num_hid))
        self.encoder = keras.Sequential(
            [self.enc_input]
            + [
                TransformerEncoder(num_hid, num_head, num_feed_forward, dropout_rate, activation)
                for _ in range(num_layers_enc)
            ]
        )
        self.GlobalAveragePooling1D = layers.GlobalAveragePooling1D(data_format='channels_last')
        self.out = layers.Dense(units=nb_classes, activation='softmax')

    def call(self, inputs):
        #x =  Time2Vector(x.shape[-1])
        x = self.encoder(inputs)
        x = self.GlobalAveragePooling1D(x)
        y = self.out(x)
        return y

# %%
train_df = pd.read_csv('/kaggle/input/tabular-playground-series-dec-2021/train.csv', sep=',')

# %%
x_train = train_df.drop(['Id', 'Soil_Type7','Soil_Type15', 'Cover_Type'], axis=1)
y_train = train_df['Cover_Type']
y_train = y_train.apply(lambda x : x - 1)
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.2, random_state=seed, shuffle=True)

# %%
# https://www.kaggle.com/c/tabular-playground-series-dec-2021/discussion/293612

def r(x):
    if x+180>360:
        return x-180
    else:
        return x+180

def fe(df):
    df['EHiElv'] = df['Horizontal_Distance_To_Roadways'] * df['Elevation']
    df['EViElv'] = df['Vertical_Distance_To_Hydrology'] * df['Elevation']
    df['Aspect2'] = df.Aspect.map(r)
    ### source: https://www.kaggle.com/c/tabular-playground-series-dec-2021/discussion/293373
    df["Aspect"][df["Aspect"] < 0] += 360
    df["Aspect"][df["Aspect"] > 359] -= 360
    df.loc[df["Hillshade_9am"] < 0, "Hillshade_9am"] = 0
    df.loc[df["Hillshade_Noon"] < 0, "Hillshade_Noon"] = 0
    df.loc[df["Hillshade_3pm"] < 0, "Hillshade_3pm"] = 0
    df.loc[df["Hillshade_9am"] > 255, "Hillshade_9am"] = 255
    df.loc[df["Hillshade_Noon"] > 255, "Hillshade_Noon"] = 255
    df.loc[df["Hillshade_3pm"] > 255, "Hillshade_3pm"] = 255
    ########
    df['Highwater'] = (df.Vertical_Distance_To_Hydrology < 0).astype(int)
    df['EVDtH'] = df.Elevation - df.Vertical_Distance_To_Hydrology
    df['EHDtH'] = df.Elevation - df.Horizontal_Distance_To_Hydrology * 0.2
    df['Euclidean_Distance_to_Hydrolody'] = (df['Horizontal_Distance_To_Hydrology']**2 + df['Vertical_Distance_To_Hydrology']**2)**0.5
    df['Manhattan_Distance_to_Hydrolody'] = df['Horizontal_Distance_To_Hydrology'] + df['Vertical_Distance_To_Hydrology']
    df['Hydro_Fire_1'] = df['Horizontal_Distance_To_Hydrology'] + df['Horizontal_Distance_To_Fire_Points']
    df['Hydro_Fire_2'] = abs(df['Horizontal_Distance_To_Hydrology'] - df['Horizontal_Distance_To_Fire_Points'])
    df['Hydro_Road_1'] = abs(df['Horizontal_Distance_To_Hydrology'] + df['Horizontal_Distance_To_Roadways'])
    df['Hydro_Road_2'] = abs(df['Horizontal_Distance_To_Hydrology'] - df['Horizontal_Distance_To_Roadways'])
    df['Fire_Road_1'] = abs(df['Horizontal_Distance_To_Fire_Points'] + df['Horizontal_Distance_To_Roadways'])
    df['Fire_Road_2'] = abs(df['Horizontal_Distance_To_Fire_Points'] - df['Horizontal_Distance_To_Roadways'])
    df['Hillshade_3pm_is_zero'] = (df.Hillshade_3pm == 0).astype(int)
    return df

# %%
x_train = fe(x_train)
x_test = fe(x_test)

# Summed features pointed out by @craigmthomas (https://www.kaggle.com/c/tabular-playground-series-dec-2021/discussion/292823)
soil_features = [x for x in x_train.columns if x.startswith("Soil_Type")]
wilderness_features = [x for x in x_train.columns if x.startswith("Wilderness_Area")]

x_train["soil_type_count"] = x_train[soil_features].sum(axis=1)
x_test["soil_type_count"] = x_test[soil_features].sum(axis=1)

x_train["wilderness_area_count"] = x_train[wilderness_features].sum(axis=1)
x_test["wilderness_area_count"] = x_test[wilderness_features].sum(axis=1)

x_train['std'] = np.std(x_train, axis=1)
x_test['std'] = np.std(x_test, axis=1)

# %%
sc = StandardScaler()

x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
x_train = x_train[:, np.newaxis, :]
x_test = x_test[:, np.newaxis, :]
nb_classes = train_df['Cover_Type'].nunique()
time_steps = 1
num_features = x_train.shape[-1]

# %%
num_heads=2
num_layers_enc=1
num_feed_forward=64

model = Transformer(num_hid=num_features,
                        time_steps=time_steps,
                        nb_classes=nb_classes,
                        num_head=num_heads,
                        num_layers_enc=num_layers_enc,
                        num_feed_forward=num_feed_forward)

opt = tf.keras.optimizers.Adam()
loss = tf.keras.losses.SparseCategoricalCrossentropy()
model.compile(optimizer=opt, loss=loss, metrics=['accuracy'])
model.fit(x_train, y_train, epochs=400, batch_size=1024, verbose=1)
print()
results = model.evaluate(x_test, y_test)[1]
print(results)
# Out:
# 2022-01-01 16:59:04.701555: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-01 16:59:04.820867: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-01 16:59:04.822007: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-01 16:59:04.824898: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-01 16:59:04.826439: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-01 16:59:04.827791: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-01 16:59:04.828999: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-01 16:59:06.932118: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-01 16:59:06.932970: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-01 16:59:06.933658: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-01 16:59:06.934344: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# 2022-01-01 16:59:08.056471: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 896000000 exceeds 10% of free system memory.
# 2022-01-01 16:59:09.007530: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 896000000 exceeds 10% of free system memory.
# 2022-01-01 16:59:09.693880: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/400
# 3125/3125 [==============================] - 13s 3ms/step - loss: 0.1579 - accuracy: 0.9372
# Epoch 2/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.1208 - accuracy: 0.9493
# Epoch 3/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.1142 - accuracy: 0.9515
# Epoch 4/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.1110 - accuracy: 0.9524
# Epoch 5/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.1085 - accuracy: 0.9533
# Epoch 6/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.1065 - accuracy: 0.9540
# Epoch 7/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.1052 - accuracy: 0.9544
# Epoch 8/400
# 3125/3125 [==============================] - 11s 4ms/step - loss: 0.1041 - accuracy: 0.9548
# Epoch 9/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.1029 - accuracy: 0.9552
# Epoch 10/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.1022 - accuracy: 0.9555
# Epoch 11/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.1014 - accuracy: 0.9559
# Epoch 12/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.1008 - accuracy: 0.9559
# Epoch 13/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.1003 - accuracy: 0.9561
# Epoch 14/400
# 3125/3125 [==============================] - 11s 4ms/step - loss: 0.0997 - accuracy: 0.9563
# Epoch 15/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0991 - accuracy: 0.9565
# Epoch 16/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0988 - accuracy: 0.9566
# Epoch 17/400
# 3125/3125 [==============================] - 11s 4ms/step - loss: 0.0984 - accuracy: 0.9567
# Epoch 18/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0981 - accuracy: 0.9568
# Epoch 19/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0977 - accuracy: 0.9569
# Epoch 20/400
# 3125/3125 [==============================] - 11s 4ms/step - loss: 0.0974 - accuracy: 0.9570
# Epoch 21/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0972 - accuracy: 0.9570
# Epoch 22/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0968 - accuracy: 0.9572
# Epoch 23/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0966 - accuracy: 0.9572
# Epoch 24/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0965 - accuracy: 0.9571
# Epoch 25/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0962 - accuracy: 0.9572
# Epoch 26/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0960 - accuracy: 0.9573
# Epoch 27/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0959 - accuracy: 0.9574
# Epoch 28/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0956 - accuracy: 0.9575
# Epoch 29/400
# 3125/3125 [==============================] - 11s 4ms/step - loss: 0.0955 - accuracy: 0.9575
# Epoch 30/400
# 3125/3125 [==============================] - 11s 4ms/step - loss: 0.0951 - accuracy: 0.9576
# Epoch 31/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0952 - accuracy: 0.9576
# Epoch 32/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0949 - accuracy: 0.9577
# Epoch 33/400
# 3125/3125 [==============================] - 11s 4ms/step - loss: 0.0946 - accuracy: 0.9579
# Epoch 34/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0946 - accuracy: 0.9578
# Epoch 35/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0945 - accuracy: 0.9578
# Epoch 36/400
# 3125/3125 [==============================] - 11s 4ms/step - loss: 0.0942 - accuracy: 0.9579
# Epoch 37/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0943 - accuracy: 0.9579
# Epoch 38/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0941 - accuracy: 0.9578
# Epoch 39/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0939 - accuracy: 0.9579
# Epoch 40/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0938 - accuracy: 0.9580
# Epoch 41/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0938 - accuracy: 0.9580
# Epoch 42/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0937 - accuracy: 0.9580
# Epoch 43/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0936 - accuracy: 0.9581
# Epoch 44/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0935 - accuracy: 0.9580
# Epoch 45/400
# 3125/3125 [==============================] - 11s 4ms/step - loss: 0.0933 - accuracy: 0.9581
# Epoch 46/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0934 - accuracy: 0.9581
# Epoch 47/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0932 - accuracy: 0.9581
# Epoch 48/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0931 - accuracy: 0.9582
# Epoch 49/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0931 - accuracy: 0.9582
# Epoch 50/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0930 - accuracy: 0.9582
# Epoch 51/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0929 - accuracy: 0.9583
# Epoch 52/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0929 - accuracy: 0.9582
# Epoch 53/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0929 - accuracy: 0.9583
# Epoch 54/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0927 - accuracy: 0.9583
# Epoch 55/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0927 - accuracy: 0.9583
# Epoch 56/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0926 - accuracy: 0.9583
# Epoch 57/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0926 - accuracy: 0.9583
# Epoch 58/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0926 - accuracy: 0.9583
# Epoch 59/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0925 - accuracy: 0.9584
# Epoch 60/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0924 - accuracy: 0.9585
# Epoch 61/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0924 - accuracy: 0.9584
# Epoch 62/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0923 - accuracy: 0.9585
# Epoch 63/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0922 - accuracy: 0.9586
# Epoch 64/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0924 - accuracy: 0.9584
# Epoch 65/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0922 - accuracy: 0.9584
# Epoch 66/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0922 - accuracy: 0.9584
# Epoch 67/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0922 - accuracy: 0.9585
# Epoch 68/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0921 - accuracy: 0.9586
# Epoch 69/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0920 - accuracy: 0.9585
# Epoch 70/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0920 - accuracy: 0.9585
# Epoch 71/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0921 - accuracy: 0.9585
# Epoch 72/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0919 - accuracy: 0.9585
# Epoch 73/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0919 - accuracy: 0.9586
# Epoch 74/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0917 - accuracy: 0.9587
# Epoch 75/400
# 3125/3125 [==============================] - 11s 4ms/step - loss: 0.0918 - accuracy: 0.9586
# Epoch 76/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0917 - accuracy: 0.9586
# Epoch 77/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0917 - accuracy: 0.9586
# Epoch 78/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0917 - accuracy: 0.9586
# Epoch 79/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0916 - accuracy: 0.9586
# Epoch 80/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0916 - accuracy: 0.9587
# Epoch 81/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0917 - accuracy: 0.9587
# Epoch 82/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0915 - accuracy: 0.9587
# Epoch 83/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0915 - accuracy: 0.9586
# Epoch 84/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0915 - accuracy: 0.9587
# Epoch 85/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0914 - accuracy: 0.9587
# Epoch 86/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0914 - accuracy: 0.9587
# Epoch 87/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0913 - accuracy: 0.9588
# Epoch 88/400
# 3125/3125 [==============================] - 11s 4ms/step - loss: 0.0914 - accuracy: 0.9587
# Epoch 89/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0912 - accuracy: 0.9588
# Epoch 90/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0912 - accuracy: 0.9588
# Epoch 91/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0914 - accuracy: 0.9587
# Epoch 92/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0912 - accuracy: 0.9587
# Epoch 93/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0912 - accuracy: 0.9587
# Epoch 94/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0912 - accuracy: 0.9588
# Epoch 95/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0912 - accuracy: 0.9587
# Epoch 96/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0911 - accuracy: 0.9589
# Epoch 97/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0911 - accuracy: 0.9588
# Epoch 98/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0911 - accuracy: 0.9588
# Epoch 99/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0910 - accuracy: 0.9588
# Epoch 100/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0909 - accuracy: 0.9589
# Epoch 101/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0910 - accuracy: 0.9589
# Epoch 102/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0909 - accuracy: 0.9590
# Epoch 103/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0909 - accuracy: 0.9589
# Epoch 104/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0909 - accuracy: 0.9589
# Epoch 105/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0909 - accuracy: 0.9589
# Epoch 106/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0908 - accuracy: 0.9589
# Epoch 107/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0908 - accuracy: 0.9589
# Epoch 108/400
# 3125/3125 [==============================] - 11s 4ms/step - loss: 0.0907 - accuracy: 0.9590
# Epoch 109/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0907 - accuracy: 0.9589
# Epoch 110/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0908 - accuracy: 0.9589
# Epoch 111/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0907 - accuracy: 0.9590
# Epoch 112/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0907 - accuracy: 0.9589
# Epoch 113/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0907 - accuracy: 0.9590
# Epoch 114/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0907 - accuracy: 0.9590
# Epoch 115/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0905 - accuracy: 0.9590
# Epoch 116/400
# 3125/3125 [==============================] - 11s 4ms/step - loss: 0.0906 - accuracy: 0.9589
# Epoch 117/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0906 - accuracy: 0.9589
# Epoch 118/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0905 - accuracy: 0.9590
# Epoch 119/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0906 - accuracy: 0.9589
# Epoch 120/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0905 - accuracy: 0.9590
# Epoch 121/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0904 - accuracy: 0.9591
# Epoch 122/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0904 - accuracy: 0.9590
# Epoch 123/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0905 - accuracy: 0.9590
# Epoch 124/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0903 - accuracy: 0.9590
# Epoch 125/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0903 - accuracy: 0.9592
# Epoch 126/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0902 - accuracy: 0.9591
# Epoch 127/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0902 - accuracy: 0.9591
# Epoch 128/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0902 - accuracy: 0.9591
# Epoch 129/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0901 - accuracy: 0.9592
# Epoch 130/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0902 - accuracy: 0.9591
# Epoch 131/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0903 - accuracy: 0.9591
# Epoch 132/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0901 - accuracy: 0.9591
# Epoch 133/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0903 - accuracy: 0.9590
# Epoch 134/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0901 - accuracy: 0.9592
# Epoch 135/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0901 - accuracy: 0.9591
# Epoch 136/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0901 - accuracy: 0.9591
# Epoch 137/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0900 - accuracy: 0.9592
# Epoch 138/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0900 - accuracy: 0.9592
# Epoch 139/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0900 - accuracy: 0.9593
# Epoch 140/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0901 - accuracy: 0.9592
# Epoch 141/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0900 - accuracy: 0.9591
# Epoch 142/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0900 - accuracy: 0.9592
# Epoch 143/400
# 3125/3125 [==============================] - 14s 5ms/step - loss: 0.0898 - accuracy: 0.9593
# Epoch 144/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0898 - accuracy: 0.9592
# Epoch 145/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0899 - accuracy: 0.9592
# Epoch 146/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0898 - accuracy: 0.9592
# Epoch 147/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0898 - accuracy: 0.9592
# Epoch 148/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0897 - accuracy: 0.9593
# Epoch 149/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0898 - accuracy: 0.9593
# Epoch 150/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0896 - accuracy: 0.9592
# Epoch 151/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0897 - accuracy: 0.9592
# Epoch 152/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0896 - accuracy: 0.9593
# Epoch 153/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0897 - accuracy: 0.9592
# Epoch 154/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0897 - accuracy: 0.9593
# Epoch 155/400
# 3125/3125 [==============================] - 11s 4ms/step - loss: 0.0897 - accuracy: 0.9592
# Epoch 156/400
# 3125/3125 [==============================] - 14s 4ms/step - loss: 0.0896 - accuracy: 0.9592
# Epoch 157/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0895 - accuracy: 0.9593
# Epoch 158/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0897 - accuracy: 0.9592
# Epoch 159/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0895 - accuracy: 0.9593
# Epoch 160/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0896 - accuracy: 0.9592
# Epoch 161/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0894 - accuracy: 0.9593
# Epoch 162/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0895 - accuracy: 0.9593
# Epoch 163/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0895 - accuracy: 0.9593
# Epoch 164/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0895 - accuracy: 0.9592
# Epoch 165/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0896 - accuracy: 0.9592
# Epoch 166/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0894 - accuracy: 0.9593
# Epoch 167/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0894 - accuracy: 0.9593
# Epoch 168/400
# 3125/3125 [==============================] - 11s 4ms/step - loss: 0.0894 - accuracy: 0.9593
# Epoch 169/400
# 3125/3125 [==============================] - 14s 4ms/step - loss: 0.0894 - accuracy: 0.9594
# Epoch 170/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0893 - accuracy: 0.9594
# Epoch 171/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0893 - accuracy: 0.9594
# Epoch 172/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0894 - accuracy: 0.9593
# Epoch 173/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0893 - accuracy: 0.9593
# Epoch 174/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0893 - accuracy: 0.9593
# Epoch 175/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0893 - accuracy: 0.9594
# Epoch 176/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0893 - accuracy: 0.9593
# Epoch 177/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0892 - accuracy: 0.9594
# Epoch 178/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0893 - accuracy: 0.9594
# Epoch 179/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0893 - accuracy: 0.9595
# Epoch 180/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0892 - accuracy: 0.9594
# Epoch 181/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0892 - accuracy: 0.9594
# Epoch 182/400
# 3125/3125 [==============================] - 14s 4ms/step - loss: 0.0892 - accuracy: 0.9594
# Epoch 183/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0891 - accuracy: 0.9594
# Epoch 184/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0892 - accuracy: 0.9594
# Epoch 185/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0890 - accuracy: 0.9595
# Epoch 186/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0892 - accuracy: 0.9594
# Epoch 187/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0892 - accuracy: 0.9594
# Epoch 188/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0891 - accuracy: 0.9595
# Epoch 189/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0891 - accuracy: 0.9594
# Epoch 190/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0892 - accuracy: 0.9595
# Epoch 191/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0890 - accuracy: 0.9594
# Epoch 192/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0891 - accuracy: 0.9593
# Epoch 193/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0890 - accuracy: 0.9595
# Epoch 194/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0891 - accuracy: 0.9594
# Epoch 195/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0890 - accuracy: 0.9595
# Epoch 196/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0889 - accuracy: 0.9594
# Epoch 197/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0890 - accuracy: 0.9594
# Epoch 198/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0890 - accuracy: 0.9594
# Epoch 199/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0890 - accuracy: 0.9595
# Epoch 200/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0889 - accuracy: 0.9595
# Epoch 201/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0888 - accuracy: 0.9595
# Epoch 202/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0889 - accuracy: 0.9595
# Epoch 203/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0888 - accuracy: 0.9595
# Epoch 204/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0890 - accuracy: 0.9595
# Epoch 205/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0889 - accuracy: 0.9594
# Epoch 206/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0888 - accuracy: 0.9595
# Epoch 207/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0888 - accuracy: 0.9595
# Epoch 208/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0889 - accuracy: 0.9596
# Epoch 209/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0889 - accuracy: 0.9595
# Epoch 210/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0889 - accuracy: 0.9595
# Epoch 211/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0888 - accuracy: 0.9596
# Epoch 212/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0889 - accuracy: 0.9595
# Epoch 213/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0888 - accuracy: 0.9595
# Epoch 214/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0889 - accuracy: 0.9594
# Epoch 215/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0888 - accuracy: 0.9595
# Epoch 216/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0888 - accuracy: 0.9595
# Epoch 217/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0888 - accuracy: 0.9596
# Epoch 218/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0888 - accuracy: 0.9595
# Epoch 219/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0887 - accuracy: 0.9595
# Epoch 220/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0887 - accuracy: 0.9596
# Epoch 221/400
# 3125/3125 [==============================] - 11s 4ms/step - loss: 0.0887 - accuracy: 0.9596
# Epoch 222/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0887 - accuracy: 0.9596
# Epoch 223/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0887 - accuracy: 0.9595
# Epoch 224/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0885 - accuracy: 0.9595
# Epoch 225/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0886 - accuracy: 0.9596
# Epoch 226/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0886 - accuracy: 0.9594
# Epoch 227/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0886 - accuracy: 0.9597
# Epoch 228/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0886 - accuracy: 0.9596
# Epoch 229/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0886 - accuracy: 0.9596
# Epoch 230/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0885 - accuracy: 0.9597
# Epoch 231/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0885 - accuracy: 0.9596
# Epoch 232/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0885 - accuracy: 0.9597
# Epoch 233/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0885 - accuracy: 0.9595
# Epoch 234/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0885 - accuracy: 0.9596
# Epoch 235/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0885 - accuracy: 0.9596
# Epoch 236/400
# 3125/3125 [==============================] - 14s 5ms/step - loss: 0.0884 - accuracy: 0.9595
# Epoch 237/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0886 - accuracy: 0.9596
# Epoch 238/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0885 - accuracy: 0.9596
# Epoch 239/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0884 - accuracy: 0.9596
# Epoch 240/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0884 - accuracy: 0.9596
# Epoch 241/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0885 - accuracy: 0.9597
# Epoch 242/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0884 - accuracy: 0.9596
# Epoch 243/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0885 - accuracy: 0.9596
# Epoch 244/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0884 - accuracy: 0.9597
# Epoch 245/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0883 - accuracy: 0.9597
# Epoch 246/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0883 - accuracy: 0.9597
# Epoch 247/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0884 - accuracy: 0.9596
# Epoch 248/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0883 - accuracy: 0.9597
# Epoch 249/400
# 3125/3125 [==============================] - 14s 4ms/step - loss: 0.0883 - accuracy: 0.9597
# Epoch 250/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0884 - accuracy: 0.9596
# Epoch 251/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0883 - accuracy: 0.9597
# Epoch 252/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0883 - accuracy: 0.9597
# Epoch 253/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0883 - accuracy: 0.9597
# Epoch 254/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0883 - accuracy: 0.9596
# Epoch 255/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0883 - accuracy: 0.9597
# Epoch 256/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0883 - accuracy: 0.9597
# Epoch 257/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0883 - accuracy: 0.9597
# Epoch 258/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0882 - accuracy: 0.9598
# Epoch 259/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0883 - accuracy: 0.9596
# Epoch 260/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0883 - accuracy: 0.9596
# Epoch 261/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0882 - accuracy: 0.9597
# Epoch 262/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0882 - accuracy: 0.9597
# Epoch 263/400
# 3125/3125 [==============================] - 14s 4ms/step - loss: 0.0880 - accuracy: 0.9597
# Epoch 264/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0882 - accuracy: 0.9597
# Epoch 265/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0882 - accuracy: 0.9597
# Epoch 266/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0882 - accuracy: 0.9597
# Epoch 267/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0881 - accuracy: 0.9598
# Epoch 268/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0883 - accuracy: 0.9597
# Epoch 269/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0881 - accuracy: 0.9597
# Epoch 270/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0882 - accuracy: 0.9596
# Epoch 271/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0881 - accuracy: 0.9597
# Epoch 272/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0881 - accuracy: 0.9597
# Epoch 273/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0882 - accuracy: 0.9597
# Epoch 274/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0881 - accuracy: 0.9597
# Epoch 275/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0882 - accuracy: 0.9597
# Epoch 276/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0881 - accuracy: 0.9597
# Epoch 277/400
# 3125/3125 [==============================] - 14s 4ms/step - loss: 0.0880 - accuracy: 0.9597
# Epoch 278/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0881 - accuracy: 0.9597
# Epoch 279/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0880 - accuracy: 0.9597
# Epoch 280/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0880 - accuracy: 0.9597
# Epoch 281/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0880 - accuracy: 0.9597
# Epoch 282/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0880 - accuracy: 0.9597
# Epoch 283/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0881 - accuracy: 0.9598
# Epoch 284/400
# 3125/3125 [==============================] - 11s 4ms/step - loss: 0.0880 - accuracy: 0.9597
# Epoch 285/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0880 - accuracy: 0.9598
# Epoch 286/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0881 - accuracy: 0.9597
# Epoch 287/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0880 - accuracy: 0.9598
# Epoch 288/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0880 - accuracy: 0.9597
# Epoch 289/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0879 - accuracy: 0.9597
# Epoch 290/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0880 - accuracy: 0.9598
# Epoch 291/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0880 - accuracy: 0.9597
# Epoch 292/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0878 - accuracy: 0.9598
# Epoch 293/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0880 - accuracy: 0.9597
# Epoch 294/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0880 - accuracy: 0.9597
# Epoch 295/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0879 - accuracy: 0.9599
# Epoch 296/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0879 - accuracy: 0.9598
# Epoch 297/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0879 - accuracy: 0.9598
# Epoch 298/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0880 - accuracy: 0.9598
# Epoch 299/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0879 - accuracy: 0.9598
# Epoch 300/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0879 - accuracy: 0.9598
# Epoch 301/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0878 - accuracy: 0.9598
# Epoch 302/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0879 - accuracy: 0.9599
# Epoch 303/400
# 3125/3125 [==============================] - 14s 5ms/step - loss: 0.0879 - accuracy: 0.9597
# Epoch 304/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0879 - accuracy: 0.9597
# Epoch 305/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0879 - accuracy: 0.9598
# Epoch 306/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0878 - accuracy: 0.9598
# Epoch 307/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0879 - accuracy: 0.9597
# Epoch 308/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0880 - accuracy: 0.9598
# Epoch 309/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0878 - accuracy: 0.9598
# Epoch 310/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0878 - accuracy: 0.9598
# Epoch 311/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0877 - accuracy: 0.9598
# Epoch 312/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0879 - accuracy: 0.9597
# Epoch 313/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0878 - accuracy: 0.9598
# Epoch 314/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0878 - accuracy: 0.9598
# Epoch 315/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0879 - accuracy: 0.9598
# Epoch 316/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0878 - accuracy: 0.9598
# Epoch 317/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0877 - accuracy: 0.9598
# Epoch 318/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0877 - accuracy: 0.9598
# Epoch 319/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0877 - accuracy: 0.9599
# Epoch 320/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0878 - accuracy: 0.9598
# Epoch 321/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0878 - accuracy: 0.9598
# Epoch 322/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0877 - accuracy: 0.9598
# Epoch 323/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0877 - accuracy: 0.9598
# Epoch 324/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0877 - accuracy: 0.9599
# Epoch 325/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0877 - accuracy: 0.9599
# Epoch 326/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0876 - accuracy: 0.9598
# Epoch 327/400
# 3125/3125 [==============================] - 11s 4ms/step - loss: 0.0877 - accuracy: 0.9599
# Epoch 328/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0877 - accuracy: 0.9598
# Epoch 329/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0877 - accuracy: 0.9599
# Epoch 330/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0877 - accuracy: 0.9599
# Epoch 331/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0876 - accuracy: 0.9598
# Epoch 332/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0877 - accuracy: 0.9598
# Epoch 333/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0877 - accuracy: 0.9599
# Epoch 334/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0877 - accuracy: 0.9599
# Epoch 335/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0877 - accuracy: 0.9599
# Epoch 336/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0877 - accuracy: 0.9598
# Epoch 337/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0878 - accuracy: 0.9597
# Epoch 338/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0877 - accuracy: 0.9598
# Epoch 339/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0876 - accuracy: 0.9598
# Epoch 340/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0876 - accuracy: 0.9599
# Epoch 341/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0876 - accuracy: 0.9599
# Epoch 342/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0876 - accuracy: 0.9599
# Epoch 343/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0875 - accuracy: 0.9598
# Epoch 344/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0876 - accuracy: 0.9599
# Epoch 345/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0876 - accuracy: 0.9600
# Epoch 346/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0876 - accuracy: 0.9598
# Epoch 347/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0876 - accuracy: 0.9598
# Epoch 348/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0876 - accuracy: 0.9598
# Epoch 349/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0876 - accuracy: 0.9599
# Epoch 350/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0875 - accuracy: 0.9598
# Epoch 351/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0876 - accuracy: 0.9598
# Epoch 352/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0876 - accuracy: 0.9598
# Epoch 353/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0875 - accuracy: 0.9598
# Epoch 354/400
# 3125/3125 [==============================] - 14s 4ms/step - loss: 0.0875 - accuracy: 0.9599
# Epoch 355/400
# 3125/3125 [==============================] - 14s 4ms/step - loss: 0.0876 - accuracy: 0.9599
# Epoch 356/400
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.0875 - accuracy: 0.9599
# Epoch 357/400
# 3125/3125 [==============================] - 11s 4ms/step - loss: 0.0876 - accuracy: 0.9599
# Epoch 358/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0875 - accuracy: 0.9599
# Epoch 359/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0876 - accuracy: 0.9598
# Epoch 360/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0875 - accuracy: 0.9600
# Epoch 361/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0874 - accuracy: 0.9600
# Epoch 362/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0876 - accuracy: 0.9598
# Epoch 363/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0875 - accuracy: 0.9599
# Epoch 364/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0874 - accuracy: 0.9599
# Epoch 365/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0875 - accuracy: 0.9599
# Epoch 366/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0876 - accuracy: 0.9599
# Epoch 367/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0875 - accuracy: 0.9599
# Epoch 368/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0875 - accuracy: 0.9599
# Epoch 369/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0875 - accuracy: 0.9599
# Epoch 370/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0874 - accuracy: 0.9600
# Epoch 371/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0875 - accuracy: 0.9599
# Epoch 372/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0875 - accuracy: 0.9599
# Epoch 373/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0875 - accuracy: 0.9599
# Epoch 374/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0876 - accuracy: 0.9598
# Epoch 375/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0875 - accuracy: 0.9599
# Epoch 376/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0876 - accuracy: 0.9598
# Epoch 377/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0875 - accuracy: 0.9599
# Epoch 378/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0875 - accuracy: 0.9599
# Epoch 379/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0875 - accuracy: 0.9599
# Epoch 380/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0874 - accuracy: 0.9598
# Epoch 381/400
# 3125/3125 [==============================] - 14s 4ms/step - loss: 0.0875 - accuracy: 0.9598
# Epoch 382/400
# 3125/3125 [==============================] - 14s 4ms/step - loss: 0.0874 - accuracy: 0.9599
# Epoch 383/400
# 3125/3125 [==============================] - 12s 4ms/step - loss: 0.0874 - accuracy: 0.9599
# Epoch 384/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0874 - accuracy: 0.9599
# Epoch 385/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0875 - accuracy: 0.9600
# Epoch 386/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0874 - accuracy: 0.9599
# Epoch 387/400
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.0874 - accuracy: 0.9600
# Epoch 388/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0875 - accuracy: 0.9598
# Epoch 389/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0874 - accuracy: 0.9599
# Epoch 390/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0874 - accuracy: 0.9599
# Epoch 391/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0873 - accuracy: 0.9600
# Epoch 392/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0874 - accuracy: 0.9599
# Epoch 393/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0874 - accuracy: 0.9599
# Epoch 394/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0872 - accuracy: 0.9600
# Epoch 395/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0874 - accuracy: 0.9599
# Epoch 396/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0874 - accuracy: 0.9599
# Epoch 397/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0873 - accuracy: 0.9599
# Epoch 398/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0874 - accuracy: 0.9599
# Epoch 399/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0874 - accuracy: 0.9599
# Epoch 400/400
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.0873 - accuracy: 0.9600
#
# 25000/25000 [==============================] - 48s 2ms/step - loss: 0.0860 - accuracy: 0.9602
# 0.9602237343788147

# %% [markdown]
# # Submission

# %%
del train_df, x_train, y_train, x_test, y_test
gc.collect()
# Out:
# 2638

# %%
test_df = pd.read_csv('/kaggle/input/tabular-playground-series-dec-2021/test.csv', sep=',')
x_test = test_df.drop(['Id', 'Soil_Type7','Soil_Type15'], axis=1)
x_test = fe(x_test)
x_test["soil_type_count"] = x_test[soil_features].sum(axis=1)
x_test["wilderness_area_count"] = x_test[wilderness_features].sum(axis=1)
x_test['std'] = np.std(x_test, axis=1)
x_test = sc.transform(x_test)
x_test = x_test[:, np.newaxis, :]

# %%
target = model.predict(x_test)
class_preds = np.argmax(target, axis=-1) + 1
ids = test_df['Id'].values
submission = pd.DataFrame({'Id' : ids, 'Cover_Type' : class_preds})

# %%
submission.head()
# Out:
#         Id  Cover_Type
# 0  4000000           2
# 1  4000001           2
# 2  4000002           2
# 3  4000003           2
# 4  4000004           2

# %%
submission.to_csv('submission.csv', index=False)
